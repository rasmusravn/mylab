# %%
import skrf as rf
# %matplotlib inline
from pylab import *

# %% [markdown]
# Plotting setup

# %%
rf.stylely()

# %% [markdown]
# Import data

# %%
ring_slot = rf.Network('data/ring slot.s2p')

# %% [markdown]
# Actual plotting

# %%
ring_slot.plot_s_db()

# %%
ring_slot.plot_s_deg(m=0,n=1)

# %%
ring_slot.plot_s_smith(lw=2)
title('Big ole Smith Chart')
# Out:
# Text(0.5, 1.0, 'Big ole Smith Chart')
